# %%
import pandas as pd
import pyfolio as pf

# Example: dummy daily returns
dates = pd.date_range(start="2023-01-01", periods=100, freq='B')
returns = pd.Series(0.001, index=dates)  # +0.1% daily return
# Out:
# c:\Users\loci_\anaconda3\Lib\site-packages\pyfolio\pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
import pandas as pd
import pyfolio as pf
import seaborn as sns

# Load the data
df = pd.read_csv(r"C:\Users\loci_\Desktop\trading_webapp\trading_webapp\DATA\output_instruments\AD1_ewma_EWMA008.csv")

# Convert the first column to datetime and set it as index
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)  # <-- this is the fix
df.set_index('Date', inplace=True)

# Extract the return series
returns = df['forecast*returns'].dropna()
returns.name = 'returns'


sns.set_context("notebook", font_scale=0.1)  # or "paper", smaller than "notebook"


# Now run the tear sheet
pf.create_full_tear_sheet(returns)
# Out:
# c:\Users\loci_\anaconda3\Lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-62.679%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2023-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2025-03-21</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>27</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-62.679%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-89.613%</td>
#     </tr>
#     <tr>
# ...
